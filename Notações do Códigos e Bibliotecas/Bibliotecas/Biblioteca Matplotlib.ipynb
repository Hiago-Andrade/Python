# %% [markdown]
# ## Biblioteca Matplotlib

# %% [markdown]
# ###### Base de dados 1 - Municípios IBGE

# %%
import pandas as pd

arqv1 = pd.read_excel(r"C:\Users\apvs\Desktop\Extras\Lista_de_CEP_CodIBGEs.xlsx")

# %%
arqv1.head()
# Out:
#   Estado    Localidade           Faixa de CEP  CEP Inicial  CEP Final  \
# 0     AC    Acrelândia  69945-000 a 69949-999     69945000   69949999
# 1     AC  Assis Brasil  69935-000 a 69939-999     69935000   69939999
# 2     AC     Brasiléia  69932-000 a 69933-999     69932000   69933999
# 3     AC        Bujari  69926-000 a 69926-999     69926000   69926999
# 4     AC      Capixaba  69931-000 a 69931-999     69931000   69931999
#
#                          Situação       Tipo de Faixa  Codigo IBGE
# 0  Não codificada por logradouros  Total do município      1200013
# 1  Não codificada por logradouros  Total do município      1200054
# 2  Não codificada por logradouros  Total do município      1200104
# 3  Não codificada por logradouros  Total do município      1200138
# 4  Não codificada por logradouros  Total do município      1200179

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

# %% [markdown]
# ###  1 - Tipos de gráficos para cada situação

# %%
Estrutura = imread(r"C:\Users\hiago.andrade\Pictures\Relações Gráficas.png")
plt.figure(figsize=(16,8))
plt.imshow(Estrutura)

# %% [markdown]
# ### 2 - Estrutura gráfica Matplotlib

# %%
Estrutura = imread(r"C:\Users\hiago.andrade\Pictures\Estrutura grafico matplotlib.png")
plt.figure(figsize=(12,8))
plt.imshow(Estrutura)

# %% [markdown]
# ### 3 - Nomenclatura gráfica matplotlib

# %%
Nomeclatura = imread(r"C:\Users\hiago.andrade\Pictures\Nomenclatura grafico matplotlib.png")
plt.figure(figsize=(15,12))
plt.imshow(Nomeclatura)

# %% [markdown]
# ### 4 - Criando Histogramas

# %%
arqv1.hist(column="Codigo IBGE", bins=10)
plt.show()

# %% [markdown]
# ### 5 - Criando gráficos de linha

# %%
import numpy as np

x1=np.arange(-1000,1000,1)
plt.plot(x1,-x1**3+4)
plt.show()

# %%
### Gráfico mais avançado 

x = [0,1,2,3,4]
y = [0,2,4,6,8]

# # Redimensione seu gráfico (dpi especifica pixels por polegada, tamanho total. Figsize o tamanho das variaveis x e y)
plt.figure(figsize=(6,6), dpi=100)

# Linha 1

# Notação do argumento da linha "2x"
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Notação taquigrafia
# fmt = '[cor][marcador][linha]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# selecionando intervalo onde queremos plotar os pontos da linha vermelha
x2 = np.arange(0,4.5, 0.5)

# Plot parte do gráfico como linha
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# restante do gráfico como um ponto
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Adicionar um título (especificar parâmetros de fonte)
plt.title('Titulo de Exemplo', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 10})

# Subtitulo de X e de Y
plt.xlabel('Titulo variável X')
plt.ylabel('Titulo variáveil Y')

# Escala das variavel X e Y
plt.xticks([0,1,2,3,4,])
plt.yticks([0,2,4,6,8,10,12,14])

# Adicionar legenda
plt.legend()

# Salvar a figura (dpi 300 é bom ao salvar para que o gráfico tenha alta resolução)
plt.savefig('gráficoexemplo.png', dpi=300)

plt.show()

# %% [markdown]
# ### 6 - Criando gráfico de Disperção

# %%
plt.scatter(arqv1["CEP Inicial"],arqv1["CEP Final"])
plt.show()

# %% [markdown]
# ### 7 - Criando gráfico de colunas

# %%
linhas = ['A', 'B', 'C']
valores = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(linhas, valores)

patterns = ['/', '', '']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.show()

# %% [markdown]
# ### 8 - Criando Boxplots do DataFrame

# %%
arqv1.boxplot()

# %%
# Criando Boxplot de colunas expecificas

arqv1.boxplot(column=["Codigo IBGE","CEP Final"])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 9 - Criando varios gráficos na mesma "Figure"

# %%
y1 = x1**2
y2 = x1**3
y3 = -x1**2


plt.subplot(2,2,1)  # 2 linas e 2 colunas, colar na 1º parte
plt.plot(x1,y1)
plt.subplot(1,2,2)
plt.plot(x1,y2)
plt.subplot(2,2,3)
plt.plot(x1,y3)

# %%
# Elevando o tamanho dos gráficos

y1 = x1**2
y2 = x1**3
y3 = -x1**2

tamanho = plt.figure(figsize=(8,8)) # Tamanho 8 da largura e 8 da altura

tamanho.add_subplot(2,2,1)  # 2 linas e 2 colunas, colar na 1º parte
plt.plot(x1,y1)
tamanho.add_subplot(1,2,2)
plt.plot(x1,y2)
tamanho.add_subplot(2,2,3)
plt.plot(x1,y3)

# %%
# Fazendo um Lop para gerar os graficos

y4 = -x1**3

y = [y1,y2,y3,y4]

tamanho = plt.figure(figsize=(8,8))

for i in range(4):
    tamanho.add_subplot(2,2,i+1)
    plt.plot(x1,y[i])

# %%
### Gráficos mais avançados 

h = np.arange(0,10,0.1)
fig1, f1_axes = plt.subplots(ncols = 2, nrows = 2, figsize = (15,10))
fig1.suptitle("Demosntração Gráfica", size = 30)

f1_axes[0, 0].plot(np.sin(h), label="seno(h)", color = "purple")
f1_axes[0, 0].plot(np.cos(h), label="coss(h)")
f1_axes[0, 0].set_title("Relação Seno x Cosseno")
f1_axes[0, 0].set_xlabel("Subtitulo 1 - Label X")
f1_axes[0, 0].set_ylabel("Subtitulo 2 - Label y")

f1_axes[0, 1].plot(np.cos(h))
f1_axes[0, 1].set_title("Cosseno de h")

f1_axes[1, 0].plot(np.tan(h), color = "orange")
f1_axes[1, 0].set_title("Tangente de h")

f1_axes[1, 1].plot(np.sin(h), color = "purple")
f1_axes[1, 1].set_title("Seno de h")
# Out:
# Text(0.5, 1.0, 'Seno de h')

# %% [markdown]
# ### 10 - Importando imagens e gerando visões

# %%
imagem = imread(r"C:/Users/apvs/Pictures/Bandeiras/MG.png")
plt.imshow(imagem)

# %%
# Importando muitas imagens ao mesmo tempo

Sudeste = ["SP","MG","ES","RJ"]

Local = "C:/Users/apvs/Pictures/Bandeiras/"

imagens = []

for i in Sudeste:
    imagem = imread(Local+str(i)+".png")
    imagens.append(imagem)
    
Figura = plt.figure(figsize=(15,8))

for i in range(4):
    Figura.add_subplot(2,2,i+1)
    plt.imshow(imagens[i])

# %% [markdown]
# ### 11 - Exemplos com dados do "Mundo Real"

# %%
# Dados Custo da Gasolina ao longo do tempo

gas = pd.read_excel(r"C:\Users\hiago.andrade\Documents\Python Scripts\Bibliotecas Python\Custo Gasolina.xlsx")

plt.figure(figsize=(8,5))

plt.title('Preço da gasolina ao longo do tempo (em Dolares)', fontdict={'fontweight':'bold', 'fontsize': 10})

plt.plot(gas.Year, gas.USA, 'b.-', label='Estados Unidos')
plt.plot(gas.Year, gas.Canada, 'r.-', label='Canadá')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='Coreia do sul')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Australia')


plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel('Ano')
plt.ylabel('US Dolares')

plt.legend()

plt.show()
